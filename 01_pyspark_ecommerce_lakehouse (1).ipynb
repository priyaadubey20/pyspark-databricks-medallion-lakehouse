# %%
# Read back from Delta Table using Spark SQL
df_saved = spark.sql("SELECT * FROM gold_customer_rankings WHERE customer_rank = 1")
display(df_saved)
display(df_saved)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_name</th><th>country</th><th>lifetime_spend</th><th>customer_rank</th></tr></thead><tbody><tr><td>Ananya Sharma</td><td>INDIA</td><td>1500.5</td><td>1</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
